# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="UYoWHkjTAYkYezIpMK2b")
project = rf.workspace("bda-0gppo").project("bda-ygbct")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# DEPRECATION: pytorch-lightning 1.5.10 has a non-standard dependency specifier torch>=1.7.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pytorch-lightning or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 6
#       4 rf = Roboflow(api_key="UYoWHkjTAYkYezIpMK2b")
#       5 project = rf.workspace("bda-0gppo").project("bda-ygbct")
# ----> 6 version = project.version(2)
#       7 dataset = version.download("yolov8")
#
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.4 torch-2.3.0+cpu CPU (AMD Ryzen 7 7730U with Radeon Graphics)
# Setup complete  (16 CPUs, 13.9 GB RAM, 260.6/474.7 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data={dataset.location}/data.yaml epochs=5 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.2.15 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.11.4 torch-2.3.0+cpu CPU (AMD Ryzen 7 7730U with Radeon Graphics)
# ...

# %%
# !yolo predict model="C:/VI/BDA/Final/project/runs/segment/train/weights/best.pt" source="https://static.skillshare.com/uploads/project/192810/cover_1242_0d14642163e162741a18dae3bdce4358.jpg"
# Out:
# Ultralytics YOLOv8.0.196  Python-3.11.4 torch-2.3.0+cpu CPU (AMD Ryzen 7 7730U with Radeon Graphics)
# YOLOv8s-seg summary (fused): 195 layers, 11788501 parameters, 0 gradients, 42.5 GFLOPs
#
# ...
#
#   0%|          | 0.00/180k [00:00<?, ?B/s]
# 100%|██████████| 180k/180k [00:00<00:00, 9.00MB/s]
# image 1/1 c:\VI\BDA\Final\project\cover_1242_0d14642163e162741a18dae3bdce4358.jpg: 448x640 (no detections), 204.2ms
# Speed: 2.6ms preprocess, 204.2ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs\segment\predict6
#  Learn more at https://docs.ultralytics.com/modes/predict
